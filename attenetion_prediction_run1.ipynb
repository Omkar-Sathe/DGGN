# %% [markdown]
# <a href="https://colab.research.google.com/github/Omkar-Sathe/DGGN/blob/main/attenetion_prediction_run1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import numpy as np

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import recall_score

import matplotlib.pyplot as plt
# %matplotlib inline

import random
import copy
from util import normalization

# %%
import warnings
warnings.filterwarnings('ignore')

X_train_gd = normalization(np.load('/content/drive/MyDrive/Dataset/DGGN/data/feature/X_train_gd_nl.npy'))
X_train_gmd = normalization(np.load('/content/drive/MyDrive/Dataset/DGGN/data/feature/X_train_gmd_nl.npy'))
X_train_gld = normalization(np.load('/content/drive/MyDrive/Dataset/DGGN/data/feature/X_train_gld_nl.npy'))

X_test_gd = normalization(np.load('/content/drive/MyDrive/Dataset/DGGN/data/feature/X_test_gd_nl.npy'))
X_test_gmd = normalization(np.load('/content/drive/MyDrive/Dataset/DGGN/data/feature/X_test_gmd_nl.npy'))
X_test_gld = normalization(np.load('/content/drive/MyDrive/Dataset/DGGN/data/feature/X_test_gld_nl.npy'))

X_gd = np.concatenate((X_train_gd,X_test_gd))
X_gmd = np.concatenate((X_train_gmd,X_test_gmd))
X_gld = np.concatenate((X_train_gld,X_test_gld))
print(X_gd.shape,X_gmd.shape,X_gld.shape)
# Out:
# (11392, 256) (11392, 256) (11392, 256)

# %%
y_train=open('/content/drive/MyDrive/Dataset/DGGN/data/balanced data/gd/y_train.txt').read().split('\n')[:-1]
y_train=[int(y) for y in y_train]
y_train=np.array(y_train)
y_train=y_train.reshape(y_train.shape[0],1)

y_test=open('/content/drive/MyDrive/Dataset/DGGN/data/balanced data/gd/y_test.txt').read().split('\n')[:-1]
y_test=[int(y) for y in y_test]
y_test = np.array(y_test)
y_test =y_test.reshape(y_test.shape[0],1)

y_train.shape, y_test.shape
# Out:
# ((9112, 1), (2280, 1))

# %%
X_gd = np.concatenate((X_train_gd,X_test_gd))
X_gmd = np.concatenate((X_train_gmd,X_test_gmd))
X_gld = np.concatenate((X_train_gld,X_test_gld))

X_gd_all =np.copy(X_gd)
X_gd_all =normalization(X_gd_all)
X_gd_all = torch.from_numpy(X_gd_all).type(torch.FloatTensor)

X_gmd_all =np.copy(X_gmd)
X_gmd_all =normalization(X_gmd_all)
X_gmd_all = torch.from_numpy(X_gmd_all).type(torch.FloatTensor)

X_gld_all =np.copy(X_gld)
X_gld_all =normalization(X_gld_all)
X_gld_all = torch.from_numpy(X_gld_all).type(torch.FloatTensor)


y_all =np.concatenate((y_train,y_test))
y_all =torch.from_numpy(y_all).type(torch.FloatTensor)

X_gd_all.size(),X_gmd_all.size(),X_gld_all.size(),y_all.size()
# Out:
# (torch.Size([11392, 256]),
#  torch.Size([11392, 256]),
#  torch.Size([11392, 256]),
#  torch.Size([11392, 1]))

# %%
class DGAClassifier(nn.Module):
#     def __init__(self,inp_size):
    def __init__(self,inp_size,inp_size_bak1,inp_size_bak2):
        super(DGAClassifier,self).__init__()
        #         self.att = nn.Linear(inp_size,inp_size)
        self.fc1 = nn.Linear(inp_size, 128)
        self.relu = nn.ReLU()
        self.dout = nn.Dropout(0.2)
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, 1)
        self.out_act = nn.Sigmoid()
        self.tanh = nn.Tanh()
        self.softmax = nn.Softmax()

        self.multihead_attn = torch.nn.MultiheadAttention(embed_dim = inp_size, num_heads =8 )
        self.linear = nn.Linear(256,128)
        self.linear256 = nn.Linear(256,256)
        self.linear384 = nn.Linear(384,256)
        self.linear768 = nn.Linear(768,256)
        self.linear512 = nn.Linear(512,256)
    def forward(self, input_,input_gmd,input_gld):
#         print("__init__:input_",input_)
#         t = self.att(input_)
#         s = self.tanh(t)
        # GD+GMD+GLD
        gd_md,attn_output_weights = self.multihead_attn(input_gmd,input_,input_)
        gd_ld,attn_output_weights = self.multihead_attn(input_gld,input_,input_)
        gd_mld = torch.cat((gd_md,gd_ld,input_),1)   # 768
        gd_mld = self.linear768(gd_mld)
        input_ = gd_mld
        # GD+GMD
        # input_gd_gmd,attn_output_weights = self.multihead_attn(input_gmd,input_,input_)
        # input_ = torch.cat((input_gd_gmd,input_),1)
        # input_ = self.linear512(input_)

        # GD+GLD
#         input_gd_gld,attn_output_weights = self.multihead_attn(input_gld,input_,input_)
#         input_ = torch.cat((input_gd_gld,input_),1)
#         input_ = self.linear384(input_)
        # GD
#         input_,attn_output_weights = self.multihead_attn(input_,input_,input_)
#         input_ = torch.cat((input_,input_),1)
#         input_ = self.linear256(input_)

        s = self.tanh(input_)       #s= torch.Size([batch_size, 128])  alpha= torch.Size([batch_size, 128])
        alpha = self.softmax(s)
        x = torch.mul(alpha,input_)
        a1 = self.fc1(x)
        h1 = self.relu(a1)
        dout = self.dout(h1)   # 损失率
        a2 = self.fc2(dout)
        h2 = self.relu(a2)
        a3 = self.out(h2)
        y = self.out_act(a3)
        return y

    def predict(self,x,x_gmd,x_gld):
        #Apply softmax to output.
        pred = self.forward(x,x_gmd,x_gld)
        ans = []
        #Pick the class with maximum weight
        for t in pred:
            if t<0.5:
                ans.append(0)
            else:
                ans.append(1)
        return torch.tensor(ans)

    def predict_probability(self,x,x_gmd,x_gld):
        pred = self.forward(x, x_gmd,x_gld)
        ans = pred
        return torch.tensor(ans)

    def predict_probability2(self,x,x_gmd,x_gld):
        pred = self.forward(x, x_gmd,x_gld)
        pred_score = pred
        ans = []
        for t in pred:
            if t<0.5:
                ans.append(0)
            else:
                ans.append(1)
        return torch.tensor(pred_score),torch.tensor(ans)

# %%
def train_cv(model, X, X_gmd, X_gld, y, opt, criterion, batch_size=64):
    model.train()
    losses = []
    for beg_i in range(0, X.size(0), batch_size):
        x_batch = X[beg_i:beg_i + batch_size, :]
        x_gmd_batch = X_gmd[beg_i:beg_i + batch_size, :]
        x_gld_batch = X_gld[beg_i:beg_i + batch_size, :]

        y_batch = y[beg_i:beg_i + batch_size, :]
        x_batch = Variable(x_batch)
        x_gmd_batch = Variable(x_gmd_batch)
        x_gld_batch = Variable(x_gld_batch)
        y_batch = Variable(y_batch)

        opt.zero_grad()
        # (1) Forward
        y_hat = clf(x_batch, x_gmd_batch, x_gld_batch)
        # (2) Compute diff
        loss = criterion(y_hat, y_batch)
        # (3) Compute gradients
        loss.backward()
        # (4) update weights
        opt.step()
        losses.append(loss.data.numpy())
    avg_loss=sum(losses)/len(losses)
    return losses,avg_loss

# %%
def avg(l):
    return sum(l)/len(l)
def compute_aupr(y,yhat):
    pre,rec,_ = precision_recall_curve(y,yhat)
    return auc(rec,pre)
def f1_score(precison, recall):
    try:
        return 2*precison*recall /(precison + recall)
    except:
        return 0.0

# %%
fpr_list=[]
tpr_list=[]
aucs = []
avg_pre = []
aupr = []
acc = []
recal = []
f1_scores_list = []
cv = StratifiedKFold(n_splits=5)
num_epochs = 50
fold_loss =[]
gmd_list = []

for i, (train,test) in enumerate(cv.split(X_gmd_all, y_all)):
    gmd_list.append((train,test))
gld_list = []
for i, (train,test) in enumerate(cv.split(X_gld_all, y_all)):
    gld_list.append((train,test))

print("start",'-'*100)
for i, (train,test) in enumerate(cv.split(X_gd_all, y_all)):

    clf = DGAClassifier(X_gd_all.size()[1],X_gmd_all.size()[1],X_gld_all.size()[1])
    opt = optim.Adam(clf.parameters(), lr=0.01, betas=(0.9, 0.999),weight_decay=1e-5)
    criterion = nn.BCELoss()

    e_losses = []
    for e in range(num_epochs):
        los,avg_loss = train_cv(clf,X_gd_all[train],X_gmd_all[train],X_gld_all[train],y_all[train],opt,criterion)
        e_losses += [avg_loss]
        print ("Fold:%d Epoch:%d/%d Train loss:%f" %(i+1,e,num_epochs,avg_loss))

    fold_loss.append(e_losses)
    # y_pred = clf.predict(X_gd_all[test], X_gmd_all[test], X_gld_all[test])
    y_pred_roc,y_pred = clf.predict_probability2(X_gd_all[test], X_gmd_all[test], X_gld_all[test])
    fpr,tpr,_= roc_curve(y_all[test],y_pred_roc)
    fpr_list.append(fpr)
    tpr_list.append(tpr)
    aucs.append(roc_auc_score(y_all[test],y_pred))
    recal.append(recall_score(y_all[test],y_pred))
    acc.append((y_pred == y_all[test]).float().mean().item())
    precision, recall, _ = precision_recall_curve(y_all[test], y_pred_roc)
    average_precision = average_precision_score(y_all[test], y_pred_roc)
    aupr.append(average_precision)
    avg_pre.append(np.mean(precision))

    # F1 Score
    # f1 = f1_score(y_all[test], y_pred)
    # f1_scores_list.append(f1)
    print("Test accuracy:%f" %acc[-1])
    print('\n')

# avr_f1_score = f1_score(avg(avg_pre), avg(recal))

print ("AUC:%f AUPR: %f Avg Pre: %f Acc: %f Recal:%f" %(avg(aucs),avg(aupr),avg(avg_pre),avg(acc),avg(recal)))
# Out:
# start ----------------------------------------------------------------------------------------------------
# Fold:1 Epoch:0/50 Train loss:0.509451
# Fold:1 Epoch:1/50 Train loss:0.479138
# Fold:1 Epoch:2/50 Train loss:0.460908
# Fold:1 Epoch:3/50 Train loss:0.459758
# Fold:1 Epoch:4/50 Train loss:0.449519
# Fold:1 Epoch:5/50 Train loss:0.461290
# Fold:1 Epoch:6/50 Train loss:0.461584
# Fold:1 Epoch:7/50 Train loss:0.458465
# Fold:1 Epoch:8/50 Train loss:0.456374
# Fold:1 Epoch:9/50 Train loss:0.453406
# Fold:1 Epoch:10/50 Train loss:0.445812
# Fold:1 Epoch:11/50 Train loss:0.470263
# Fold:1 Epoch:12/50 Train loss:0.465868
# Fold:1 Epoch:13/50 Train loss:0.446341
# Fold:1 Epoch:14/50 Train loss:0.430591
# Fold:1 Epoch:15/50 Train loss:0.447116
# Fold:1 Epoch:16/50 Train loss:0.433051
# Fold:1 Epoch:17/50 Train loss:0.449002
# Fold:1 Epoch:18/50 Train loss:0.441751
# Fold:1 Epoch:19/50 Train loss:0.424727
# Fold:1 Epoch:20/50 Train loss:0.439962
# Fold:1 Epoch:21/50 Train loss:0.447537
# Fold:1 Epoch:22/50 Train loss:0.422815
# Fold:1 Epoch:23/50 Train loss:0.436598
# Fold:1 Epoch:24/50 Train loss:0.427752
# Fold:1 Epoch:25/50 Train loss:0.430470
# Fold:1 Epoch:26/50 Train loss:0.423731
# Fold:1 Epoch:27/50 Train loss:0.434964
# Fold:1 Epoch:28/50 Train loss:0.409332
# Fold:1 Epoch:29/50 Train loss:0.398226
# Fold:1 Epoch:30/50 Train loss:0.422284
# Fold:1 Epoch:31/50 Train loss:0.431256
# Fold:1 Epoch:32/50 Train loss:0.412946
# Fold:1 Epoch:33/50 Train loss:0.428155
# Fold:1 Epoch:34/50 Train loss:0.401953
# Fold:1 Epoch:35/50 Train loss:0.401666
# Fold:1 Epoch:36/50 Train loss:0.397564
# Fold:1 Epoch:37/50 Train loss:0.420625
# Fold:1 Epoch:38/50 Train loss:0.427314
# Fold:1 Epoch:39/50 Train loss:0.430001
# Fold:1 Epoch:40/50 Train loss:0.418605
# Fold:1 Epoch:41/50 Train loss:0.420413
# Fold:1 Epoch:42/50 Train loss:0.393345
# Fold:1 Epoch:43/50 Train loss:0.390033
# Fold:1 Epoch:44/50 Train loss:0.403436
# Fold:1 Epoch:45/50 Train loss:0.409442
# Fold:1 Epoch:46/50 Train loss:0.420434
# Fold:1 Epoch:47/50 Train loss:0.423158
# Fold:1 Epoch:48/50 Train loss:0.415736
# Fold:1 Epoch:49/50 Train loss:0.417932
# Test accuracy:0.500056
#
#
# Fold:2 Epoch:0/50 Train loss:0.487758
# Fold:2 Epoch:1/50 Train loss:0.467489
# Fold:2 Epoch:2/50 Train loss:0.438875
# Fold:2 Epoch:3/50 Train loss:0.437998
# Fold:2 Epoch:4/50 Train loss:0.451903
# Fold:2 Epoch:5/50 Train loss:0.484104
# Fold:2 Epoch:6/50 Train loss:0.469553
# Fold:2 Epoch:7/50 Train loss:0.450257
# Fold:2 Epoch:8/50 Train loss:0.443276
# Fold:2 Epoch:9/50 Train loss:0.454523
# Fold:2 Epoch:10/50 Train loss:0.453331
# Fold:2 Epoch:11/50 Train loss:0.454195
# Fold:2 Epoch:12/50 Train loss:0.474799
# Fold:2 Epoch:13/50 Train loss:0.450421
# Fold:2 Epoch:14/50 Train loss:0.484936
# Fold:2 Epoch:15/50 Train loss:0.486378
# Fold:2 Epoch:16/50 Train loss:0.451214
# Fold:2 Epoch:17/50 Train loss:0.431602
# Fold:2 Epoch:18/50 Train loss:0.435338
# Fold:2 Epoch:19/50 Train loss:0.429904
# Fold:2 Epoch:20/50 Train loss:0.435385
# Fold:2 Epoch:21/50 Train loss:0.413156
# Fold:2 Epoch:22/50 Train loss:0.425111
# Fold:2 Epoch:23/50 Train loss:0.432487
# Fold:2 Epoch:24/50 Train loss:0.412029
# Fold:2 Epoch:25/50 Train loss:0.421182
# Fold:2 Epoch:26/50 Train loss:0.421761
# Fold:2 Epoch:27/50 Train loss:0.421870
# Fold:2 Epoch:28/50 Train loss:0.416573
# Fold:2 Epoch:29/50 Train loss:0.432557
# Fold:2 Epoch:30/50 Train loss:0.436604
# Fold:2 Epoch:31/50 Train loss:0.469505
# Fold:2 Epoch:32/50 Train loss:0.449670
# Fold:2 Epoch:33/50 Train loss:0.438233
# Fold:2 Epoch:34/50 Train loss:0.418499
# Fold:2 Epoch:35/50 Train loss:0.415648
# Fold:2 Epoch:36/50 Train loss:0.398490
# Fold:2 Epoch:37/50 Train loss:0.404572
# Fold:2 Epoch:38/50 Train loss:0.406949
# Fold:2 Epoch:39/50 Train loss:0.402433
# Fold:2 Epoch:40/50 Train loss:0.441790
# Fold:2 Epoch:41/50 Train loss:0.442021
# Fold:2 Epoch:42/50 Train loss:0.413867
# Fold:2 Epoch:43/50 Train loss:0.379341
# Fold:2 Epoch:44/50 Train loss:0.378474
# Fold:2 Epoch:45/50 Train loss:0.377057
# Fold:2 Epoch:46/50 Train loss:0.385346
# Fold:2 Epoch:47/50 Train loss:0.378636
# Fold:2 Epoch:48/50 Train loss:0.377274
# Fold:2 Epoch:49/50 Train loss:0.369227
# Test accuracy:0.500027
#
#
# Fold:3 Epoch:0/50 Train loss:0.559995
# Fold:3 Epoch:1/50 Train loss:0.459843
# Fold:3 Epoch:2/50 Train loss:0.462718
# Fold:3 Epoch:3/50 Train loss:0.439975
# Fold:3 Epoch:4/50 Train loss:0.437171
# Fold:3 Epoch:5/50 Train loss:0.449879
# Fold:3 Epoch:6/50 Train loss:0.461223
# Fold:3 Epoch:7/50 Train loss:0.440967
# Fold:3 Epoch:8/50 Train loss:0.460813
# Fold:3 Epoch:9/50 Train loss:0.435501
# Fold:3 Epoch:10/50 Train loss:0.433808
# Fold:3 Epoch:11/50 Train loss:0.441834
# Fold:3 Epoch:12/50 Train loss:0.441051
# Fold:3 Epoch:13/50 Train loss:0.434434
# Fold:3 Epoch:14/50 Train loss:0.432496
# Fold:3 Epoch:15/50 Train loss:0.438431
# Fold:3 Epoch:16/50 Train loss:0.434320
# Fold:3 Epoch:17/50 Train loss:0.448585
# Fold:3 Epoch:18/50 Train loss:0.443191
# Fold:3 Epoch:19/50 Train loss:0.421577
# Fold:3 Epoch:20/50 Train loss:0.426864
# Fold:3 Epoch:21/50 Train loss:0.400053
# Fold:3 Epoch:22/50 Train loss:0.412585
# Fold:3 Epoch:23/50 Train loss:0.440963
# Fold:3 Epoch:24/50 Train loss:0.407128
# Fold:3 Epoch:25/50 Train loss:0.412436
# Fold:3 Epoch:26/50 Train loss:0.400873
# Fold:3 Epoch:27/50 Train loss:0.408975
# Fold:3 Epoch:28/50 Train loss:0.421003
# Fold:3 Epoch:29/50 Train loss:0.392055
# Fold:3 Epoch:30/50 Train loss:0.387584
# Fold:3 Epoch:31/50 Train loss:0.400972
# Fold:3 Epoch:32/50 Train loss:0.411694
# Fold:3 Epoch:33/50 Train loss:0.410915
# Fold:3 Epoch:34/50 Train loss:0.397629
# Fold:3 Epoch:35/50 Train loss:0.405511
# Fold:3 Epoch:36/50 Train loss:0.503671
# Fold:3 Epoch:37/50 Train loss:0.455712
# Fold:3 Epoch:38/50 Train loss:0.440653
# Fold:3 Epoch:39/50 Train loss:0.404938
# Fold:3 Epoch:40/50 Train loss:0.401755
# Fold:3 Epoch:41/50 Train loss:0.425145
# Fold:3 Epoch:42/50 Train loss:0.403866
# Fold:3 Epoch:43/50 Train loss:0.402912
# Fold:3 Epoch:44/50 Train loss:0.381328
# Fold:3 Epoch:45/50 Train loss:0.389512
# Fold:3 Epoch:46/50 Train loss:0.405848
# Fold:3 Epoch:47/50 Train loss:0.387145
# Fold:3 Epoch:48/50 Train loss:0.405233
# Fold:3 Epoch:49/50 Train loss:0.387364
# Test accuracy:0.500000
#
#
# Fold:4 Epoch:0/50 Train loss:0.517253
# Fold:4 Epoch:1/50 Train loss:0.455261
# Fold:4 Epoch:2/50 Train loss:0.450087
# Fold:4 Epoch:3/50 Train loss:0.439668
# Fold:4 Epoch:4/50 Train loss:0.451008
# Fold:4 Epoch:5/50 Train loss:0.452490
# Fold:4 Epoch:6/50 Train loss:0.472062
# Fold:4 Epoch:7/50 Train loss:0.453437
# Fold:4 Epoch:8/50 Train loss:0.452609
# Fold:4 Epoch:9/50 Train loss:0.469202
# Fold:4 Epoch:10/50 Train loss:0.461075
# Fold:4 Epoch:11/50 Train loss:0.455334
# Fold:4 Epoch:12/50 Train loss:0.456492
# Fold:4 Epoch:13/50 Train loss:0.474699
# Fold:4 Epoch:14/50 Train loss:0.489986
# Fold:4 Epoch:15/50 Train loss:0.454025
# Fold:4 Epoch:16/50 Train loss:0.436635
# Fold:4 Epoch:17/50 Train loss:0.448623
# Fold:4 Epoch:18/50 Train loss:0.423287
# Fold:4 Epoch:19/50 Train loss:0.410825
# Fold:4 Epoch:20/50 Train loss:0.410174
# Fold:4 Epoch:21/50 Train loss:0.422436
# Fold:4 Epoch:22/50 Train loss:0.440966
# Fold:4 Epoch:23/50 Train loss:0.442284
# Fold:4 Epoch:24/50 Train loss:0.422345
# Fold:4 Epoch:25/50 Train loss:0.426288
# Fold:4 Epoch:26/50 Train loss:0.415745
# Fold:4 Epoch:27/50 Train loss:0.423779
# Fold:4 Epoch:28/50 Train loss:0.428489
# Fold:4 Epoch:29/50 Train loss:0.412805
# Fold:4 Epoch:30/50 Train loss:0.431674
# Fold:4 Epoch:31/50 Train loss:0.416295
# Fold:4 Epoch:32/50 Train loss:0.401188
# Fold:4 Epoch:33/50 Train loss:0.410618
# Fold:4 Epoch:34/50 Train loss:0.393113
# Fold:4 Epoch:35/50 Train loss:0.399801
# Fold:4 Epoch:36/50 Train loss:0.425217
# Fold:4 Epoch:37/50 Train loss:0.410798
# Fold:4 Epoch:38/50 Train loss:0.397239
# Fold:4 Epoch:39/50 Train loss:0.400324
# Fold:4 Epoch:40/50 Train loss:0.410900
# Fold:4 Epoch:41/50 Train loss:0.433426
# Fold:4 Epoch:42/50 Train loss:0.420701
# Fold:4 Epoch:43/50 Train loss:0.426127
# Fold:4 Epoch:44/50 Train loss:0.395163
# Fold:4 Epoch:45/50 Train loss:0.382311
# Fold:4 Epoch:46/50 Train loss:0.412067
# Fold:4 Epoch:47/50 Train loss:0.417690
# Fold:4 Epoch:48/50 Train loss:0.384558
# Fold:4 Epoch:49/50 Train loss:0.385508
# Test accuracy:0.500000
#
#
# Fold:5 Epoch:0/50 Train loss:0.512182
# Fold:5 Epoch:1/50 Train loss:0.465779
# Fold:5 Epoch:2/50 Train loss:0.443469
# Fold:5 Epoch:3/50 Train loss:0.444474
# Fold:5 Epoch:4/50 Train loss:0.447279
# Fold:5 Epoch:5/50 Train loss:0.439462
# Fold:5 Epoch:6/50 Train loss:0.441398
# Fold:5 Epoch:7/50 Train loss:0.475218
# Fold:5 Epoch:8/50 Train loss:0.499615
# Fold:5 Epoch:9/50 Train loss:0.453566
# Fold:5 Epoch:10/50 Train loss:0.462318
# Fold:5 Epoch:11/50 Train loss:0.447849
# Fold:5 Epoch:12/50 Train loss:0.438768
# Fold:5 Epoch:13/50 Train loss:0.434676
# Fold:5 Epoch:14/50 Train loss:0.455341
# Fold:5 Epoch:15/50 Train loss:0.438271
# Fold:5 Epoch:16/50 Train loss:0.431829
# Fold:5 Epoch:17/50 Train loss:0.435597
# Fold:5 Epoch:18/50 Train loss:0.416177
# Fold:5 Epoch:19/50 Train loss:0.421579
# Fold:5 Epoch:20/50 Train loss:0.432929
# Fold:5 Epoch:21/50 Train loss:0.431675
# Fold:5 Epoch:22/50 Train loss:0.422618
# Fold:5 Epoch:23/50 Train loss:0.404130
# Fold:5 Epoch:24/50 Train loss:0.409683
# Fold:5 Epoch:25/50 Train loss:0.426517
# Fold:5 Epoch:26/50 Train loss:0.391943
# Fold:5 Epoch:27/50 Train loss:0.413793
# Fold:5 Epoch:28/50 Train loss:0.392463
# Fold:5 Epoch:29/50 Train loss:0.385688
# Fold:5 Epoch:30/50 Train loss:0.417102
# Fold:5 Epoch:31/50 Train loss:0.415801
# Fold:5 Epoch:32/50 Train loss:0.409156
# Fold:5 Epoch:33/50 Train loss:0.400049
# Fold:5 Epoch:34/50 Train loss:0.393478
# Fold:5 Epoch:35/50 Train loss:0.401567
# Fold:5 Epoch:36/50 Train loss:0.391420
# Fold:5 Epoch:37/50 Train loss:0.410242
# Fold:5 Epoch:38/50 Train loss:0.441246
# Fold:5 Epoch:39/50 Train loss:0.426367
# Fold:5 Epoch:40/50 Train loss:0.392462
# Fold:5 Epoch:41/50 Train loss:0.424723
# Fold:5 Epoch:42/50 Train loss:0.405022
# Fold:5 Epoch:43/50 Train loss:0.382792
# Fold:5 Epoch:44/50 Train loss:0.396478
# Fold:5 Epoch:45/50 Train loss:0.401602
# Fold:5 Epoch:46/50 Train loss:0.398543
# Fold:5 Epoch:47/50 Train loss:0.380700
# Fold:5 Epoch:48/50 Train loss:0.384302
# Fold:5 Epoch:49/50 Train loss:0.392001
# Test accuracy:0.500000
#
#
# AUC:0.760342 AUPR: 0.842710 Avg Pre: 0.753865 Acc: 0.500017 Recal:0.729095

# %%
for i in range(len(aucs)):
    plt.plot(fpr_list[i],tpr_list[i],label="Fold-"+str(i+1)+"(auc="+str(round(aucs[i],3))+")")
    plt.plot([0,1], [0,1], color='navy', lw=1, linestyle='--')
    plt.legend()
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.xlim([0, 1.0])
plt.ylim([0, 1.05])
plt.title('ROC curves of MHAGP')
# plt.savefig('./data/nl_ROC.svg',dpi=300)
plt.show()
